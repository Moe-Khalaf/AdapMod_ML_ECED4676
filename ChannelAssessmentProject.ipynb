# %% [markdown]
# # Channel Assessment Model Training
# ## 1. Introduction
# This notebook contains the process for both generating a dataset for channel assessment, as well as the training of a model. This work is being done with the purpose of complimenting the proposed adaptive modulation architecture mentioned in the project report.

# %%
import numpy as np
import pandas as pd
import random
from google.colab import drive
import seaborn as sns
import matplotlib.pyplot as plt
drive.mount('/content/drive') # Mounting the Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. User Defined Functions
# The following functions are designed wih the intent of generating the channel assessment dataset. Each data sample contains a signal with channel conditions applied to it, a measurement of the signal to noise ratio, and a measurement of the multipath applied. In this case, the signal is the input, or "features", while the channel conditions are the labels.

# %%
# Function Definitions
def generate_random_bits(len):
    """
    Generate a bitstream to transmit.

    :param len: Length of the bitstream.
    :return: NumPy array containing the bitstream.
    """
    return np.array([random.randint(0, 1) for i in range(len)])

def generate_BFSK_Signal_vectorized(bitstream, f1, f2, fs, fc, T_symbol):
    """
    Generate a BFSK signal using vectorization.

    :param bitstream: Bitstream to modulate.
    :param f1: Frequency representing '0'.
    :param f2: Frequency representing '1'.
    :param fs: Sampling frequency.
    :param T_symbol: Symbol duration.
    :return: BFSK signal as a numpy array.
    """
    num_bits = len(bitstream)
    t = np.arange(0, num_bits * T_symbol, 1/fs)  # Full time vector for all symbols

    # Initialize the waveform
    f_waveform = np.zeros(len(t), dtype=complex)

    # Create the waveform for each bit in the bitstream
    for i, bit in enumerate(bitstream):
        start_index = i * int(T_symbol * fs)
        end_index = start_index + int(T_symbol * fs)
        frequency = f1 if bit == 0 else f2
        f_waveform[start_index:end_index] = np.exp(2j * np.pi * frequency * t[start_index:end_index])

    # Upconvert with Carrier Frequency
    signal_upconverted = f_waveform*np.exp(2j*np.pi*fc*t)
    return signal_upconverted

def apply_multipath(signal, delays, attenuations, sampling_freq):
    """
    Apply multipath effects to a signal without extending its length.

    :param signal: The original signal (numpy array).
    :param delays: List of delays for each path in seconds.
    :param attenuations: List of attenuation factors for each path (0 to 1).
    :param sampling_freq: Sampling frequency of the signal.
    :return: Signal with multipath effects applied.
    """
    multipath_signal = np.copy(signal)  # Start with the original signal

    # Add each delayed and attenuated path
    for delay, attenuation in zip(delays, attenuations):
        delay_samples = int(delay * sampling_freq)
        delayed_signal = np.zeros(len(signal))
        delayed_signal[:len(signal) - delay_samples] = signal[delay_samples:] * attenuation
        multipath_signal += delayed_signal

    return multipath_signal

def apply_awgn_snr(signal, snr_db): # Applies addiive white gausian noise to signal
    """
    Apply Additive White Gaussian Noise to a signal based on a given SNR in dB.

    :param signal: The original signal (numpy array).
    :param snr_db: Desired Signal-to-Noise Ratio in dB.
    :return: Signal with AWGN applied.
    """
    # Calculate signal power
    signal_power = np.mean(np.abs(signal)**2)

    # Convert SNR from dB to linear scale
    snr_linear = 10 ** (snr_db / 10)

    # Calculate noise power based on SNR
    noise_power = signal_power / snr_linear

    # Generate white Gaussian noise
    noise = np.random.normal(0, np.sqrt(noise_power), len(signal))

    # Add noise to the signal
    noisy_signal = signal + noise

    return noisy_signal

def generate_random_mp_conditions():
    """
    Generate a random set of multipath conditions with ordered delays and attenuations scaling linearly with delay.

    :return: List of multipath conditions.
    """
    alpha = -0.02645 # Attenuation constant (Approximation based of of kinslers fundamentals of acoustics)
    # Generate number of paths (Can later be modified to be random in future work)
    num_paths = 5

    # Generate and sort random delays
    delays = np.sort(np.random.uniform(0, 0.04, num_paths))

    # Calculate attenuations that decay exponentially with delay
    min_attenuation = np.random.uniform(0.01, 0.6)
    attenuations = [min_attenuation * np.exp(-delay * alpha/max(delays)) for delay in delays]

    # Ensure that attenuations do not exceed min_attenuation
    attenuations = [max(att, min_attenuation) for att in attenuations]

    return delays, attenuations

# %% [markdown]
# ## 3. Dataset generation
# The following code generates a the dataset as a pandas dataframe. Here, the same BFSK signal is used in all data samples as a pilot signal. Each sample then only varies in the channel conditions.

# %%
# Parameters
num_signals = 3000  # Number of signals to generate
bitstream_length = 25  # Length of each bitstream

# BFSK Parameters
f1, f2, fs, fc, T_symbol = -2500, 2500, 30000, 10000, 0.02



# Initialize DataFrame with expanded columns for delays and attenuations
columns = ['BFSK_Signal_Real', 'BFSK_Signal_Imag'] + [f'Delay_{i+1}' for i in range(5)] + [f'Attenuation_{i+1}' for i in range(5)] + ['SNR']
df = pd.DataFrame(columns=columns)


# Generate Random Bitstream
bitstream = generate_random_bits(bitstream_length)

# Generate BFSK signal
bfsk_signal = generate_BFSK_Signal_vectorized(bitstream, f1, f2, fs, fc, T_symbol)

# Generate Samples
for _ in range(num_signals):
    # Generate random channel conditions
    delays, attenuations = generate_random_mp_conditions()
    snr_db = np.random.uniform(0, 30)

    # Apply channel conditions
    multipath_signal = apply_multipath(bfsk_signal, delays, attenuations, fs)

    # Apply AWGN
    final_signal = apply_awgn_snr(multipath_signal, snr_db)
    real_part = [num.real for num in final_signal]
    imag_part = [num.imag for num in final_signal]

    # Create a new row and append it
    new_row = {
        'BFSK_Signal_Real': real_part,
        'BFSK_Signal_Imag': imag_part,
        **{f'Delay_{i+1}': delays[i] for i in range(5)},
        **{f'Attenuation_{i+1}': attenuations[i] for i in range(5)},
        'SNR': snr_db
    }
    df = pd.concat([df, pd.DataFrame([new_row], columns=columns)], ignore_index=True)
df

# %% [markdown]
# The data is separated here into a features dataframe and a labels dataframe

# %%
# Expand the real and imaginary parts into separate DataFrames
real_df = pd.DataFrame(df['BFSK_Signal_Real'].tolist())
imag_df = pd.DataFrame(df['BFSK_Signal_Imag'].tolist())

# Concatenate the two DataFrames Horizontally
combined_df = pd.concat([real_df, imag_df], axis=1)
# Create the label data frame
combined_df_labels = df[[f'Delay_{i+1}' for i in range(5)] +
                        [f'Attenuation_{i+1}' for i in range(5)] +
                        ['SNR']]

# %%
# Export the dataframes to csv files
combined_df.to_csv('/content/drive/MyDrive/Data/channelassessment_dataset.csv')
combined_df_labels.to_csv('/content/drive/MyDrive/Data/channelassessment_labels.csv')

# %% [markdown]
# # 4. Model Training
# The following code executes the training of the channel assessment model based off of the generated dataset

# %%
from keras.models import Sequential, Model
from keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, Dropout, concatenate
from keras.metrics import MeanSquaredError
import keras.backend as K
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import ast

# %%
# Load in the Dataset
features = pd.read_csv('/content/drive/MyDrive/Data/channelassessment_dataset.csv')
features = features.drop(features.columns[0], axis=1)
labels = pd.read_csv('/content/drive/MyDrive/Data/channelassessment_labels.csv')
labels = labels.drop(labels.columns[0], axis=1)
labels
# Out:
#        Delay_1   Delay_2   Delay_3   Delay_4   Delay_5  Attenuation_1  \
# 0     0.000550  0.017011  0.030143  0.033087  0.039937       0.193122
# 1     0.009064  0.020881  0.025850  0.036450  0.038164       0.273188
# 2     0.009163  0.017331  0.022362  0.025306  0.030978       0.106103
# 3     0.001868  0.004718  0.005007  0.024131  0.029304       0.187878
# 4     0.003178  0.016070  0.033937  0.035424  0.035780       0.334001
# ...        ...       ...       ...       ...       ...            ...
# 2995  0.007017  0.007573  0.008531  0.012059  0.028958       0.039182
# 2996  0.001345  0.004210  0.015866  0.028622  0.037921       0.353267
# 2997  0.001676  0.007371  0.008344  0.017282  0.029801       0.240566
# 2998  0.004731  0.004795  0.017286  0.023010  0.026878       0.259851
# 2999  0.005954  0.011404  0.021540  0.026033  0.027905       0.144685
#
#       Attenuation_2  Attenuation_3  Attenuation_4  Attenuation_5        SNR
# 0          0.195239       0.196944       0.197329       0.198226  15.688562
# 1          0.275435       0.276385       0.278423       0.278754  28.335931
# 2          0.106846       0.107305       0.107576       0.108098  21.399036
# 3          0.188362       0.188411       0.191692       0.192589   6.949596
# 4          0.337199       0.341682       0.342058       0.342148   3.479821
# ...             ...            ...            ...            ...        ...
# 2995       0.039202       0.039236       0.039363       0.039975   0.379460
# 2996       0.353974       0.356863       0.360053       0.362396  21.372654
# 2997       0.241785       0.241994       0.243921       0.246647   7.469077
# 2998       0.259868       0.263082       0.264568       0.265577  10.325804
# 2999       0.145435       0.146839       0.147465       0.147727   7.068915
#
# [3000 rows x 11 columns]

# %%
def regression_accuracy(y_true, y_pred, threshold=0.1):
    """
    A custom accuracy metric for regression tasks.
    Considers predictions within a certain range of the actual values as accurate.
    :param y_true: The actual values.
    :param y_pred: The predicted values.
    :param threshold: The acceptable range.
    """
    return K.mean(K.less_equal(K.abs(y_true - y_pred), threshold), axis=-1)

# %% [markdown]
# This following function defines the creation of the CNN model that will be used for channel assessment. One thing thats worth noting is how the model splits into three branches for the three predictions. All branches share the convolutional layers. Where they differ is after the convolutional layers.
#
# The branch that predicts the multipath delays takes in the output of the convolutional layers and feeds that output to a dense layer, followed by the final output.
#
# The branch that predicts the multipath attenuations takes in a combination of the convolutional layer output, and the delay branch output and then sends the combination of the two through several dense layers. The reason this has been done is because it was desirable to factor in the results for the delay predictions into the preditions of attenuation in case there was a relationship that could be taken advantage of.
#
# The branch that predicts snr goes straight to the output following the convolution layers.

# %%
def create_multi_output_model(input_shape, num_delays=5, num_attenuations=5):
    # Input layer
    input_layer = Input(shape=input_shape)

    # Shared Convolutional layers
    x = Conv1D(filters=128, kernel_size=3, activation='relu')(input_layer)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)

    x = Conv1D(filters=64, kernel_size=3, activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)

    x = Conv1D(filters=64, kernel_size=3, activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)

    x = Conv1D(filters=32, kernel_size=3, activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)

    x = Conv1D(filters=16, kernel_size=3, activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)

    x = Conv1D(filters=8, kernel_size=3, activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)

    x = Flatten()(x)

    # Branch for Delays
    x_delays = Dense(64, activation='relu')(x)
    delays_output = Dense(num_delays, name='delays_output')(x_delays)

    # Combine the output of the delays branch with the flattened features
    combined_features = concatenate([x, delays_output])

    # Enhanced branch for attenuations
    x_attenuations = Dense(128, activation='relu')(combined_features)  # First dense layer with more neurons
    x_attenuations = Dropout(0.3)(x_attenuations)  # Dropout layer for regularization
    x_attenuations = Dense(64, activation='relu')(x_attenuations)  # Second dense layer
    x_attenuations = Dropout(0.3)(x_attenuations)
    x_attenuations = Dense(32, activation='relu')(x_attenuations)  # Third dense layer
    attenuations_output = Dense(num_attenuations, name='attenuations_output')(x_attenuations)

    # Branch for SNR
    snr_output = Dense(1, name='snr_output')(x)  # Output for SNR

    # Define the model
    model = Model(inputs=input_layer, outputs=[snr_output, delays_output, attenuations_output])

    # Compile the model
    model.compile(optimizer='adam',
                  loss={'snr_output': 'mse', 'delays_output': 'mse', 'attenuations_output': 'mse'},
                  metrics={'snr_output': regression_accuracy, 'delays_output': regression_accuracy, 'attenuations_output': regression_accuracy})

    return model

# %% [markdown]
# The following code divides up the data between training and validation

# %%
time_steps = features.shape[1]
input_shape = (time_steps, 1)
model = create_multi_output_model(input_shape)

X_train, X_val, y_train, y_val = train_test_split(
    features,
    combined_df_labels,
    test_size=0.2,  # 20% of the data will be used for validation
    random_state=42  # for reproducibility of results
)

# Extracting individual label sets from the training and validation sets
y_train_snr = y_train['SNR']
y_train_delays = y_train[[f'Delay_{i+1}' for i in range(5)]]
y_train_attenuations = y_train[[f'Attenuation_{i+1}' for i in range(5)]]

y_val_snr = y_val['SNR']
y_val_delays = y_val[[f'Delay_{i+1}' for i in range(5)]]
y_val_attenuations = y_val[[f'Attenuation_{i+1}' for i in range(5)]]

# %% [markdown]
# The code is trained here.

# %%
# Train the model
history = model.fit(
    X_train,
    {'snr_output': y_train_snr, 'delays_output': y_train_delays, 'attenuations_output': y_train_attenuations},
    epochs=30,  # Number of epochs, adjust as needed
    batch_size=32,  # Batch size, adjust as needed
    validation_data=(X_val, {'snr_output': y_val_snr, 'delays_output': y_val_delays, 'attenuations_output': y_val_attenuations})
)
# Out:
# Epoch 1/30
# 75/75 [==============================] - 8s 60ms/step - loss: 100.2009 - snr_output_loss: 99.9445 - delays_output_loss: 0.1277 - attenuations_output_loss: 0.1286 - snr_output_regression_accuracy: 0.0083 - delays_output_regression_accuracy: 0.6092 - attenuations_output_regression_accuracy: 0.3126 - val_loss: 124.7223 - val_snr_output_loss: 124.6764 - val_delays_output_loss: 4.2339e-04 - val_attenuations_output_loss: 0.0455 - val_snr_output_regression_accuracy: 0.0067 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3703
# Epoch 2/30
# 75/75 [==============================] - 4s 51ms/step - loss: 70.8021 - snr_output_loss: 70.7761 - delays_output_loss: 3.3377e-04 - attenuations_output_loss: 0.0256 - snr_output_regression_accuracy: 0.0067 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4116 - val_loss: 133.0193 - val_snr_output_loss: 132.9981 - val_delays_output_loss: 2.2391e-04 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3960
# Epoch 3/30
# 75/75 [==============================] - 4s 51ms/step - loss: 25.4523 - snr_output_loss: 25.4311 - delays_output_loss: 1.7035e-04 - attenuations_output_loss: 0.0210 - snr_output_regression_accuracy: 0.0167 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4067 - val_loss: 90.2185 - val_snr_output_loss: 90.1974 - val_delays_output_loss: 1.1108e-04 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3943
# Epoch 4/30
# 75/75 [==============================] - 4s 51ms/step - loss: 7.4205 - snr_output_loss: 7.3995 - delays_output_loss: 8.9831e-05 - attenuations_output_loss: 0.0210 - snr_output_regression_accuracy: 0.0342 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.3991 - val_loss: 51.6479 - val_snr_output_loss: 51.6268 - val_delays_output_loss: 6.3777e-05 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3930
# Epoch 5/30
# 75/75 [==============================] - 4s 51ms/step - loss: 3.0858 - snr_output_loss: 3.0648 - delays_output_loss: 5.8185e-05 - attenuations_output_loss: 0.0209 - snr_output_regression_accuracy: 0.0558 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4050 - val_loss: 55.0854 - val_snr_output_loss: 55.0644 - val_delays_output_loss: 4.8137e-05 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3930
# Epoch 6/30
# 75/75 [==============================] - 4s 52ms/step - loss: 2.7296 - snr_output_loss: 2.7088 - delays_output_loss: 4.7805e-05 - attenuations_output_loss: 0.0208 - snr_output_regression_accuracy: 0.0504 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4059 - val_loss: 59.5279 - val_snr_output_loss: 59.5068 - val_delays_output_loss: 4.3810e-05 - val_attenuations_output_loss: 0.0211 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3953
# Epoch 7/30
# 75/75 [==============================] - 4s 51ms/step - loss: 2.1846 - snr_output_loss: 2.1637 - delays_output_loss: 4.4882e-05 - attenuations_output_loss: 0.0209 - snr_output_regression_accuracy: 0.0483 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.3973 - val_loss: 64.6868 - val_snr_output_loss: 64.6658 - val_delays_output_loss: 4.2973e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3930
# Epoch 8/30
# 75/75 [==============================] - 4s 51ms/step - loss: 2.0729 - snr_output_loss: 2.0521 - delays_output_loss: 4.7362e-05 - attenuations_output_loss: 0.0207 - snr_output_regression_accuracy: 0.0550 - delays_output_regression_accuracy: 0.9998 - attenuations_output_regression_accuracy: 0.3975 - val_loss: 49.7834 - val_snr_output_loss: 49.7625 - val_delays_output_loss: 4.2878e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3937
# Epoch 9/30
# 75/75 [==============================] - 4s 51ms/step - loss: 1.4878 - snr_output_loss: 1.4673 - delays_output_loss: 4.4009e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0750 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4033 - val_loss: 47.8522 - val_snr_output_loss: 47.8311 - val_delays_output_loss: 4.2946e-05 - val_attenuations_output_loss: 0.0211 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3943
# Epoch 10/30
# 75/75 [==============================] - 4s 51ms/step - loss: 1.4677 - snr_output_loss: 1.4471 - delays_output_loss: 4.3983e-05 - attenuations_output_loss: 0.0206 - snr_output_regression_accuracy: 0.0792 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4052 - val_loss: 46.6352 - val_snr_output_loss: 46.6142 - val_delays_output_loss: 4.2974e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3970
# Epoch 11/30
# 75/75 [==============================] - 4s 51ms/step - loss: 1.3301 - snr_output_loss: 1.3094 - delays_output_loss: 4.3981e-05 - attenuations_output_loss: 0.0207 - snr_output_regression_accuracy: 0.0679 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4000 - val_loss: 44.2010 - val_snr_output_loss: 44.1800 - val_delays_output_loss: 4.3013e-05 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3937
# Epoch 12/30
# 75/75 [==============================] - 4s 51ms/step - loss: 1.2633 - snr_output_loss: 1.2426 - delays_output_loss: 4.3976e-05 - attenuations_output_loss: 0.0207 - snr_output_regression_accuracy: 0.0746 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4032 - val_loss: 43.2083 - val_snr_output_loss: 43.1873 - val_delays_output_loss: 4.2996e-05 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3917
# Epoch 13/30
# 75/75 [==============================] - 4s 51ms/step - loss: 1.0337 - snr_output_loss: 1.0131 - delays_output_loss: 4.3984e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0904 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.3989 - val_loss: 39.1408 - val_snr_output_loss: 39.1197 - val_delays_output_loss: 4.2999e-05 - val_attenuations_output_loss: 0.0211 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3953
# Epoch 14/30
# 75/75 [==============================] - 4s 51ms/step - loss: 1.1144 - snr_output_loss: 1.0938 - delays_output_loss: 4.4484e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0808 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4002 - val_loss: 38.6824 - val_snr_output_loss: 38.6614 - val_delays_output_loss: 4.2984e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3957
# Epoch 15/30
# 75/75 [==============================] - 4s 51ms/step - loss: 1.1219 - snr_output_loss: 1.1014 - delays_output_loss: 4.4167e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0867 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.3988 - val_loss: 43.6523 - val_snr_output_loss: 43.6313 - val_delays_output_loss: 4.2965e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3963
# Epoch 16/30
# 75/75 [==============================] - 4s 51ms/step - loss: 1.2215 - snr_output_loss: 1.2008 - delays_output_loss: 4.3988e-05 - attenuations_output_loss: 0.0206 - snr_output_regression_accuracy: 0.0800 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4012 - val_loss: 40.8923 - val_snr_output_loss: 40.8713 - val_delays_output_loss: 4.3010e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3963
# Epoch 17/30
# 75/75 [==============================] - 4s 51ms/step - loss: 0.9063 - snr_output_loss: 0.8858 - delays_output_loss: 4.3982e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0804 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4008 - val_loss: 44.5464 - val_snr_output_loss: 44.5254 - val_delays_output_loss: 4.2971e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3940
# Epoch 18/30
# 75/75 [==============================] - 4s 51ms/step - loss: 0.8391 - snr_output_loss: 0.8185 - delays_output_loss: 4.3992e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0979 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4031 - val_loss: 39.0678 - val_snr_output_loss: 39.0468 - val_delays_output_loss: 4.2972e-05 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3933
# Epoch 19/30
# 75/75 [==============================] - 4s 51ms/step - loss: 0.7158 - snr_output_loss: 0.6953 - delays_output_loss: 4.3992e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0996 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.3988 - val_loss: 35.8519 - val_snr_output_loss: 35.8310 - val_delays_output_loss: 4.2994e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3930
# Epoch 20/30
# 75/75 [==============================] - 4s 52ms/step - loss: 0.6089 - snr_output_loss: 0.5883 - delays_output_loss: 4.4162e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.1192 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4016 - val_loss: 35.8134 - val_snr_output_loss: 35.7923 - val_delays_output_loss: 4.2959e-05 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3917
# Epoch 21/30
# 75/75 [==============================] - 4s 51ms/step - loss: 0.7256 - snr_output_loss: 0.7050 - delays_output_loss: 4.4001e-05 - attenuations_output_loss: 0.0206 - snr_output_regression_accuracy: 0.1050 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4031 - val_loss: 42.8185 - val_snr_output_loss: 42.7975 - val_delays_output_loss: 4.2971e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3937
# Epoch 22/30
# 75/75 [==============================] - 4s 52ms/step - loss: 0.7478 - snr_output_loss: 0.7272 - delays_output_loss: 4.4003e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0979 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4018 - val_loss: 31.5924 - val_snr_output_loss: 31.5714 - val_delays_output_loss: 4.2935e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3963
# Epoch 23/30
# 75/75 [==============================] - 4s 52ms/step - loss: 0.6285 - snr_output_loss: 0.6079 - delays_output_loss: 4.3991e-05 - attenuations_output_loss: 0.0206 - snr_output_regression_accuracy: 0.1079 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.3984 - val_loss: 37.5340 - val_snr_output_loss: 37.5130 - val_delays_output_loss: 4.2966e-05 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3940
# Epoch 24/30
# 75/75 [==============================] - 4s 52ms/step - loss: 0.6767 - snr_output_loss: 0.6562 - delays_output_loss: 4.3990e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.1096 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4008 - val_loss: 31.6904 - val_snr_output_loss: 31.6695 - val_delays_output_loss: 4.2961e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3960
# Epoch 25/30
# 75/75 [==============================] - 4s 52ms/step - loss: 0.6495 - snr_output_loss: 0.6289 - delays_output_loss: 4.3992e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.1146 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4022 - val_loss: 33.6618 - val_snr_output_loss: 33.6408 - val_delays_output_loss: 4.2998e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3943
# Epoch 26/30
# 75/75 [==============================] - 4s 51ms/step - loss: 0.6625 - snr_output_loss: 0.6419 - delays_output_loss: 4.3999e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.0983 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4007 - val_loss: 30.9078 - val_snr_output_loss: 30.8865 - val_delays_output_loss: 4.2961e-05 - val_attenuations_output_loss: 0.0213 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3977
# Epoch 27/30
# 75/75 [==============================] - 4s 52ms/step - loss: 0.5251 - snr_output_loss: 0.5046 - delays_output_loss: 4.4001e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.1196 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4027 - val_loss: 33.9366 - val_snr_output_loss: 33.9156 - val_delays_output_loss: 4.2957e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3947
# Epoch 28/30
# 75/75 [==============================] - 4s 52ms/step - loss: 0.5091 - snr_output_loss: 0.4885 - delays_output_loss: 4.4002e-05 - attenuations_output_loss: 0.0206 - snr_output_regression_accuracy: 0.1292 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.4022 - val_loss: 27.7176 - val_snr_output_loss: 27.6967 - val_delays_output_loss: 4.3014e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3953
# Epoch 29/30
# 75/75 [==============================] - 4s 51ms/step - loss: 0.6951 - snr_output_loss: 0.6745 - delays_output_loss: 4.3989e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.1112 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.3999 - val_loss: 34.2431 - val_snr_output_loss: 34.2221 - val_delays_output_loss: 4.2951e-05 - val_attenuations_output_loss: 0.0210 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3910
# Epoch 30/30
# 75/75 [==============================] - 4s 51ms/step - loss: 0.5383 - snr_output_loss: 0.5177 - delays_output_loss: 4.4003e-05 - attenuations_output_loss: 0.0205 - snr_output_regression_accuracy: 0.1242 - delays_output_regression_accuracy: 1.0000 - attenuations_output_regression_accuracy: 0.3990 - val_loss: 30.6898 - val_snr_output_loss: 30.6689 - val_delays_output_loss: 4.2989e-05 - val_attenuations_output_loss: 0.0209 - val_snr_output_regression_accuracy: 0.0000e+00 - val_delays_output_regression_accuracy: 1.0000 - val_attenuations_output_regression_accuracy: 0.3953

# %% [markdown]
# ## 5. Evaluation and Results
# From the above results, it can be seen that the predictions for Multipath are good, however, the prediction for SNR has little to no accuracy. From this, we can say that this model can be used for multipath assessment, however, more traditional methods of noise measurement may be more suitable. Ultimately however, in future work, tweaks can be made in order to better determine the attenuation of the multipath signals.
#
# In summary
# - SNR Validation Accuracy: 0.00%
# - Multipath Delay Validation Accuracy: 99.99%
# - Multipath Attenuation Validation Accuracy: 39.53%
